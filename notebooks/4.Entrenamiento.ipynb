# %% [markdown]
# # Entrenamiento

# %% [markdown]
# El entrenamiento contemplará el uso de los algoritmos supervisados CO y FHMM provistos por NILMTK, usando la señal de potencia activa de los dispositivos. Para cada algoritmo se entrenarán varios modelos usando diferentes periodos de muestreo entre 1 segundo y 10 minutos. Esto permitirá posteriormente comparar los modelos

# %% [markdown]
# Librerías y otros ajustes:

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rcParams
import warnings
warnings. filterwarnings("ignore")
plt.style.use('bmh')

from nilmtk import TimeFrame, MeterGroup, HDFDataStore, DataSet

deps = DataSet('C:/data/DEPS.h5')
elec = deps.buildings[1].elec
labels = pd.DataFrame({'Instances': list(range(1,11)),
                       'Meters': ['Main_RST', 'Main_R', 'Main_S', 'Main_T', 'Lights_1','Lights_2', 'HVAC_1', 'HVAC_2', 'HVAC_4', 'Rack']})
Meters={}
for x in range(len(labels)): Meters[elec[x+1]]=labels['Meters'][x]

# %% [markdown]
# ## Set de Entrenamiento

# %%
#Set para entrenamiento
train = DataSet('C:/data/DEPS.h5')
train.set_window(start="2020-02-25 00:00:00", end="2020-03-03 23:59:59")
train_elec = train.buildings[1].elec

#Dispositivos para entrenamiento
train_Devices = train_elec.select(instance=[5,6,7,8,9,10])
train_Devices
# Out:
# MeterGroup(meters=
#   ElecMeter(instance=5, building=1, dataset='DEPS', appliances=[Appliance(type='light', instance=1)])
#   ElecMeter(instance=6, building=1, dataset='DEPS', appliances=[Appliance(type='light', instance=2)])
#   ElecMeter(instance=7, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=1)])
#   ElecMeter(instance=8, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=2)])
#   ElecMeter(instance=9, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=3)])
#   ElecMeter(instance=10, building=1, dataset='DEPS', appliances=[Appliance(type='server computer', instance=1)])
# )

# %%
rcParams['figure.figsize'] = (10, 7)

fig, ((ax1, ax2),(ax3, ax4),(ax5, ax6)) = plt.subplots(3, 2, sharex=True,
                                                       gridspec_kw={'hspace': 0.2, 'wspace': 0.2})
#colores
colors=['tab:blue','tab:orange','tab:green','tab:olive','tab:purple','tab:cyan']
m=5
for ax in fig.get_axes(): 
    next(train_elec[m].load(ac_type='active', sample_period=60,
                            resample_kwargs={'how':'first'})).plot(ax=ax, legend=False, color=colors[m-5])   
    ax.set_ylabel('Power(W)')
    ax1.set_ylim(auto=True)
    ax.minorticks_off()
    ax.set_xticklabels(labels=['Feb-25','Feb-26','Feb-27','Feb-28','Feb-29','Mar-01','Mar-02','Mar-03'], ha ='left')    
    ax.set_title(labels['Meters'][m-1], fontsize=12).set_position([.11, 1])
    c=['k','k','k','b','b','b','k','k']
    [t.set_color(i) for (i,t) in zip(c, ax.xaxis.get_ticklabels())]
    m=m+1

ax6.set_ylim(90,130)   
plt.savefig('C:/data/images/4.1_Plot_train.svg', bbox_inches='tight', transparent=True)
pass

# %% [markdown]
# ### Modelos

# %% [markdown]
# #### CO

# %%
from nilmtk.legacy.disaggregate import CombinatorialOptimisation
CO=CombinatorialOptimisation() #variable del modelo
CO.train(train_Devices) #entrenamiento del modelo CO
# Out:
# Training model for submeter 'ElecMeter(instance=5, building=1, dataset='DEPS', appliances=[Appliance(type='light', instance=1)])' with 2 states
# Training model for submeter 'ElecMeter(instance=6, building=1, dataset='DEPS', appliances=[Appliance(type='light', instance=2)])' with 2 states
# Training model for submeter 'ElecMeter(instance=7, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=1)])' with 3 states
# Training model for submeter 'ElecMeter(instance=8, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=2)])' with 3 states
# Training model for submeter 'ElecMeter(instance=9, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=3)])' with 3 states
# Training model for submeter 'ElecMeter(instance=10, building=1, dataset='DEPS', appliances=[Appliance(type='server computer', instance=1)])' with 3 states
# Done training!

# %% [markdown]
# #### FHMM

# %%
from nilmtk.legacy.disaggregate import FHMM
FHMM=FHMM() #variable del modelo
FHMM.train(train_Devices) #entrenamiento del modelo FHMM
FHMM
# Out:
# Training model for submeter 'ElecMeter(instance=5, building=1, dataset='DEPS', appliances=[Appliance(type='light', instance=1)])' with 2 states
# Training model for submeter 'ElecMeter(instance=6, building=1, dataset='DEPS', appliances=[Appliance(type='light', instance=2)])' with 2 states
# Training model for submeter 'ElecMeter(instance=7, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=1)])' with 3 states
# Training model for submeter 'ElecMeter(instance=8, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=2)])' with 3 states
# Training model for submeter 'ElecMeter(instance=9, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=3)])' with 3 states
# Training model for submeter 'ElecMeter(instance=10, building=1, dataset='DEPS', appliances=[Appliance(type='server computer', instance=1)])' with 3 states

# %% [markdown]
# ### Entrenamiento:  Modelo CO y  Modelo FHMM  - FIRST 1s

# %% [markdown]
# Con el método first tiene sentido entrenar un solo modelo, cada 1 segundo, el que servirá para desagregar señales obtenidas cada 10s, 30s, 60s, 5min, 10min. 15min y 30min. Cabe recordar que con este modelo emula la adquisición de datos instantáneos en el periodo definido.

# %%
from nilmtk.legacy.disaggregate import CombinatorialOptimisation, FHMM

dir_models = 'C:/data/NILM/Models/'
times = {} #almacena tiempos de ejecución
null={} #diccionario nulo
    
t = []
models={'CO':CombinatorialOptimisation(), 'FHMM':FHMM()}

for model_name, model in models.items():
    print("*"*20 + ' ' + model_name + "*"*20)
    #Entrenamiento
    model.MIN_CHUNK_LENGTH = 1
    import time
    start = time.time()
    model.train(train_Devices,
                num_states_dict={}, #diccionario de estados nulo, por defecto
                ac_type='active', #potencia activa, por defecto
                sample_period=1, #cambio de muestreo
                resample_kwargs={'how':'first'})#método 

    t.append(round(time.time()-start,2)) #tiempo de simulación

    #Guarda modelo
    model_dir = dir_models + model_name + '_1s_first_model.pickle'
    model.export_model(model_dir) 

times['1s'] = t #tiempo de simulación
times_t1 = pd.DataFrame(times,index=['CO_first', 'FHMM_first'])
    
print('\n\nDone!')
# Out:
# ******************** CO********************
# Training model for submeter 'ElecMeter(instance=5, building=1, dataset='DEPS', appliances=[Appliance(type='light', instance=1)])' with 2 states
# Training model for submeter 'ElecMeter(instance=6, building=1, dataset='DEPS', appliances=[Appliance(type='light', instance=2)])' with 2 states
# Training model for submeter 'ElecMeter(instance=7, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=1)])' with 3 states
# Training model for submeter 'ElecMeter(instance=8, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=2)])' with 3 states
# Training model for submeter 'ElecMeter(instance=9, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=3)])' with 3 states
# Training model for submeter 'ElecMeter(instance=10, building=1, dataset='DEPS', appliances=[Appliance(type='server computer', instance=1)])' with 3 states
# Done training!
# ******************** FHMM********************
# Training model for submeter 'ElecMeter(instance=5, building=1, dataset='DEPS', appliances=[Appliance(type='light', instance=1)])' with 2 states
# Training model for submeter 'ElecMeter(instance=6, building=1, dataset='DEPS', appliances=[Appliance(type='light', instance=2)])' with 2 states
# Training model for submeter 'ElecMeter(instance=7, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=1)])' with 3 states
# Training model for submeter 'ElecMeter(instance=8, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=2)])' with 3 states
# Training model for submeter 'ElecMeter(instance=9, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=3)])' with 3 states
# Training model for submeter 'ElecMeter(instance=10, building=1, dataset='DEPS', appliances=[Appliance(type='server computer', instance=1)])' with 3 states
#
#
# Done!

# %%
#tiempos de simulación: entrenamiento
times_t1.transpose()
# Out:
#     CO_first  FHMM_first
# 1s      4.12       49.73

# %% [markdown]
# ### Modelos CO y  Modelos FHMM  - MEAN y MEDIAN
# Debido que los métodos mean y median realizan un cálculo sobre la señal original, solo tiene sentido entrenar modelos para periodos de muestreo diferentes a al original de 1 segundo. Por esto, para estos método solo se entrenarán modelos para los periodos 10s, 30s, 60s, 5min , 10min, 15min y 30 min

# %%
from nilmtk.legacy.disaggregate import CombinatorialOptimisation, FHMM

periods = {'10s':10 , '30s':30, '60s':60, '5min':60*5, '10min':60*10, '15min':60*15, '30min':60*30}
methods = ['mean', 'median']
dir_models = 'C:/data/NILM/Models/'
times = {} #almacena tiempos de ejecución
null= {} #diccionario nulo
    
for sp_name, sp in periods.items():
    t = []
    
    for method in methods:
        models={'CO':CombinatorialOptimisation(), 'FHMM':FHMM()}

        for model_name, model in models.items():
            print("*"*20 + ' ' + model_name + ' ' + sp_name+ ' ' + method + "*"*20)
            #Entrenamiento
            model.MIN_CHUNK_LENGTH = 1
            import time
            start = time.time()
            model.train(train_Devices,
                        num_states_dict={ }, #diccionario de estados nulo, por defecto
                        ac_type='active', #potencia activa, por defecto
                        sample_period=sp, #cambio de muestreo
                        resample_kwargs={'how':method}) #método

            t.append(round(time.time()-start,2)) #tiempo de simulación

            #Guarda modelo
            model_dir = dir_models + model_name + '_' + sp_name + '_' + method + '_model.pickle'
            model.export_model(model_dir) 

    times[sp_name] = t #tiempo de simulación

times_t2 = pd.DataFrame(times,index=['CO_mean', 'FHMM_mean', 'CO_median', 'FHMM_median'])
    
print('\n\nDone!')
# Out:
# ******************** CO 10s mean********************
# Training model for submeter 'ElecMeter(instance=5, building=1, dataset='DEPS', appliances=[Appliance(type='light', instance=1)])' with 3 states
# Training model for submeter 'ElecMeter(instance=6, building=1, dataset='DEPS', appliances=[Appliance(type='light', instance=2)])' with 3 states
# Training model for submeter 'ElecMeter(instance=7, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=1)])' with 3 states
# Training model for submeter 'ElecMeter(instance=8, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=2)])' with 3 states
# Training model for submeter 'ElecMeter(instance=9, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=3)])' with 3 states
# Training model for submeter 'ElecMeter(instance=10, building=1, dataset='DEPS', appliances=[Appliance(type='server computer', instance=1)])' with 3 states
# Done training!
# ******************** FHMM 10s mean********************
# Training model for submeter 'ElecMeter(instance=5, building=1, dataset='DEPS', appliances=[Appliance(type='light', instance=1)])' with 3 states
# Training model for submeter 'ElecMeter(instance=6, building=1, dataset='DEPS', appliances=[Appliance(type='light', instance=2)])' with 3 states
# Training model for submeter 'ElecMeter(instance=7, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=1)])' with 3 states
# Training model for submeter 'ElecMeter(instance=8, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=2)])' with 3 states
# Training model for submeter 'ElecMeter(instance=9, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=3)])' with 3 states
# Training model for submeter 'ElecMeter(instance=10, building=1, dataset='DEPS', appliances=[Appliance(type='server computer', instance=1)])' with 3 states
# ******************** CO 10s median********************
# Training model for submeter 'ElecMeter(instance=5, building=1, dataset='DEPS', appliances=[Appliance(type='light', instance=1)])' with 3 states
# Training model for submeter 'ElecMeter(instance=6, building=1, dataset='DEPS', appliances=[Appliance(type='light', instance=2)])' with 3 states
# Training model for submeter 'ElecMeter(instance=7, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=1)])' with 3 states
# Training model for submeter 'ElecMeter(instance=8, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=2)])' with 3 states
# Training model for submeter 'ElecMeter(instance=9, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=3)])' with 3 states
# Training model for submeter 'ElecMeter(instance=10, building=1, dataset='DEPS', appliances=[Appliance(type='server computer', instance=1)])' with 3 states
# Done training!
# ******************** FHMM 10s median********************
# Training model for submeter 'ElecMeter(instance=5, building=1, dataset='DEPS', appliances=[Appliance(type='light', instance=1)])' with 2 states
# Training model for submeter 'ElecMeter(instance=6, building=1, dataset='DEPS', appliances=[Appliance(type='light', instance=2)])' with 3 states
# Training model for submeter 'ElecMeter(instance=7, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=1)])' with 3 states
# Training model for submeter 'ElecMeter(instance=8, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=2)])' with 3 states
# Training model for submeter 'ElecMeter(instance=9, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=3)])' with 3 states
# Training model for submeter 'ElecMeter(instance=10, building=1, dataset='DEPS', appliances=[Appliance(type='server computer', instance=1)])' with 3 states
# ******************** CO 30s mean********************
# Training model for submeter 'ElecMeter(instance=5, building=1, dataset='DEPS', appliances=[Appliance(type='light', instance=1)])' with 3 states
# Training model for submeter 'ElecMeter(instance=6, building=1, dataset='DEPS', appliances=[Appliance(type='light', instance=2)])' with 3 states
# Training model for submeter 'ElecMeter(instance=7, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=1)])' with 3 states
# Training model for submeter 'ElecMeter(instance=8, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=2)])' with 3 states
# Training model for submeter 'ElecMeter(instance=9, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=3)])' with 3 states
# Training model for submeter 'ElecMeter(instance=10, building=1, dataset='DEPS', appliances=[Appliance(type='server computer', instance=1)])' with 3 states
# Done training!
# ******************** FHMM 30s mean********************
# Training model for submeter 'ElecMeter(instance=5, building=1, dataset='DEPS', appliances=[Appliance(type='light', instance=1)])' with 3 states
# Training model for submeter 'ElecMeter(instance=6, building=1, dataset='DEPS', appliances=[Appliance(type='light', instance=2)])' with 3 states
# Training model for submeter 'ElecMeter(instance=7, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=1)])' with 3 states
# Training model for submeter 'ElecMeter(instance=8, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=2)])' with 3 states
# Training model for submeter 'ElecMeter(instance=9, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=3)])' with 3 states
# Training model for submeter 'ElecMeter(instance=10, building=1, dataset='DEPS', appliances=[Appliance(type='server computer', instance=1)])' with 3 states
# ******************** CO 30s median********************
# Training model for submeter 'ElecMeter(instance=5, building=1, dataset='DEPS', appliances=[Appliance(type='light', instance=1)])' with 2 states
# Training model for submeter 'ElecMeter(instance=6, building=1, dataset='DEPS', appliances=[Appliance(type='light', instance=2)])' with 2 states
# Training model for submeter 'ElecMeter(instance=7, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=1)])' with 3 states
# Training model for submeter 'ElecMeter(instance=8, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=2)])' with 3 states
# Training model for submeter 'ElecMeter(instance=9, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=3)])' with 3 states
# Training model for submeter 'ElecMeter(instance=10, building=1, dataset='DEPS', appliances=[Appliance(type='server computer', instance=1)])' with 3 states
# Done training!
# ******************** FHMM 30s median********************
# Training model for submeter 'ElecMeter(instance=5, building=1, dataset='DEPS', appliances=[Appliance(type='light', instance=1)])' with 2 states
# Training model for submeter 'ElecMeter(instance=6, building=1, dataset='DEPS', appliances=[Appliance(type='light', instance=2)])' with 2 states
# Training model for submeter 'ElecMeter(instance=7, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=1)])' with 3 states
# Training model for submeter 'ElecMeter(instance=8, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=2)])' with 3 states
# Training model for submeter 'ElecMeter(instance=9, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=3)])' with 3 states
# Training model for submeter 'ElecMeter(instance=10, building=1, dataset='DEPS', appliances=[Appliance(type='server computer', instance=1)])' with 3 states
# ******************** CO 60s mean********************
# Training model for submeter 'ElecMeter(instance=5, building=1, dataset='DEPS', appliances=[Appliance(type='light', instance=1)])' with 3 states
# Training model for submeter 'ElecMeter(instance=6, building=1, dataset='DEPS', appliances=[Appliance(type='light', instance=2)])' with 3 states
# Training model for submeter 'ElecMeter(instance=7, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=1)])' with 3 states
# Training model for submeter 'ElecMeter(instance=8, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=2)])' with 3 states
# Training model for submeter 'ElecMeter(instance=9, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=3)])' with 3 states
# Training model for submeter 'ElecMeter(instance=10, building=1, dataset='DEPS', appliances=[Appliance(type='server computer', instance=1)])' with 3 states
# Done training!
# ******************** FHMM 60s mean********************
# Training model for submeter 'ElecMeter(instance=5, building=1, dataset='DEPS', appliances=[Appliance(type='light', instance=1)])' with 3 states
# Training model for submeter 'ElecMeter(instance=6, building=1, dataset='DEPS', appliances=[Appliance(type='light', instance=2)])' with 3 states
# Training model for submeter 'ElecMeter(instance=7, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=1)])' with 3 states
# Training model for submeter 'ElecMeter(instance=8, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=2)])' with 3 states
# Training model for submeter 'ElecMeter(instance=9, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=3)])' with 3 states
# Training model for submeter 'ElecMeter(instance=10, building=1, dataset='DEPS', appliances=[Appliance(type='server computer', instance=1)])' with 3 states
# ******************** CO 60s median********************
# Training model for submeter 'ElecMeter(instance=5, building=1, dataset='DEPS', appliances=[Appliance(type='light', instance=1)])' with 2 states
# Training model for submeter 'ElecMeter(instance=6, building=1, dataset='DEPS', appliances=[Appliance(type='light', instance=2)])' with 2 states
# Training model for submeter 'ElecMeter(instance=7, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=1)])' with 3 states
# Training model for submeter 'ElecMeter(instance=8, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=2)])' with 3 states
# Training model for submeter 'ElecMeter(instance=9, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=3)])' with 3 states
# Training model for submeter 'ElecMeter(instance=10, building=1, dataset='DEPS', appliances=[Appliance(type='server computer', instance=1)])' with 3 states
# Done training!
# ******************** FHMM 60s median********************
# Training model for submeter 'ElecMeter(instance=5, building=1, dataset='DEPS', appliances=[Appliance(type='light', instance=1)])' with 2 states
# Training model for submeter 'ElecMeter(instance=6, building=1, dataset='DEPS', appliances=[Appliance(type='light', instance=2)])' with 2 states
# Training model for submeter 'ElecMeter(instance=7, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=1)])' with 3 states
# Training model for submeter 'ElecMeter(instance=8, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=2)])' with 3 states
# Training model for submeter 'ElecMeter(instance=9, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=3)])' with 3 states
# Training model for submeter 'ElecMeter(instance=10, building=1, dataset='DEPS', appliances=[Appliance(type='server computer', instance=1)])' with 3 states
# ******************** CO 5min mean********************
# Training model for submeter 'ElecMeter(instance=5, building=1, dataset='DEPS', appliances=[Appliance(type='light', instance=1)])' with 3 states
# Training model for submeter 'ElecMeter(instance=6, building=1, dataset='DEPS', appliances=[Appliance(type='light', instance=2)])' with 3 states
# Training model for submeter 'ElecMeter(instance=7, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=1)])' with 3 states
# Training model for submeter 'ElecMeter(instance=8, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=2)])' with 3 states
# Training model for submeter 'ElecMeter(instance=9, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=3)])' with 3 states
# Training model for submeter 'ElecMeter(instance=10, building=1, dataset='DEPS', appliances=[Appliance(type='server computer', instance=1)])' with 3 states
# Done training!
# ******************** FHMM 5min mean********************
# Training model for submeter 'ElecMeter(instance=5, building=1, dataset='DEPS', appliances=[Appliance(type='light', instance=1)])' with 3 states
# Training model for submeter 'ElecMeter(instance=6, building=1, dataset='DEPS', appliances=[Appliance(type='light', instance=2)])' with 3 states
# Training model for submeter 'ElecMeter(instance=7, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=1)])' with 3 states
# Training model for submeter 'ElecMeter(instance=8, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=2)])' with 3 states
# Training model for submeter 'ElecMeter(instance=9, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=3)])' with 3 states
# Training model for submeter 'ElecMeter(instance=10, building=1, dataset='DEPS', appliances=[Appliance(type='server computer', instance=1)])' with 3 states
# ******************** CO 5min median********************
# Training model for submeter 'ElecMeter(instance=5, building=1, dataset='DEPS', appliances=[Appliance(type='light', instance=1)])' with 2 states
# Training model for submeter 'ElecMeter(instance=6, building=1, dataset='DEPS', appliances=[Appliance(type='light', instance=2)])' with 2 states
# Training model for submeter 'ElecMeter(instance=7, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=1)])' with 3 states
# Training model for submeter 'ElecMeter(instance=8, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=2)])' with 3 states
# Training model for submeter 'ElecMeter(instance=9, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=3)])' with 3 states
# Training model for submeter 'ElecMeter(instance=10, building=1, dataset='DEPS', appliances=[Appliance(type='server computer', instance=1)])' with 3 states
# Done training!
# ******************** FHMM 5min median********************
# Training model for submeter 'ElecMeter(instance=5, building=1, dataset='DEPS', appliances=[Appliance(type='light', instance=1)])' with 2 states
# Training model for submeter 'ElecMeter(instance=6, building=1, dataset='DEPS', appliances=[Appliance(type='light', instance=2)])' with 2 states
# Training model for submeter 'ElecMeter(instance=7, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=1)])' with 3 states
# Training model for submeter 'ElecMeter(instance=8, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=2)])' with 3 states
# Training model for submeter 'ElecMeter(instance=9, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=3)])' with 3 states
# Training model for submeter 'ElecMeter(instance=10, building=1, dataset='DEPS', appliances=[Appliance(type='server computer', instance=1)])' with 3 states
# ******************** CO 10min mean********************
# Training model for submeter 'ElecMeter(instance=5, building=1, dataset='DEPS', appliances=[Appliance(type='light', instance=1)])' with 3 states
# Training model for submeter 'ElecMeter(instance=6, building=1, dataset='DEPS', appliances=[Appliance(type='light', instance=2)])' with 3 states
# Training model for submeter 'ElecMeter(instance=7, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=1)])' with 3 states
# Training model for submeter 'ElecMeter(instance=8, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=2)])' with 3 states
# Training model for submeter 'ElecMeter(instance=9, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=3)])' with 3 states
# Training model for submeter 'ElecMeter(instance=10, building=1, dataset='DEPS', appliances=[Appliance(type='server computer', instance=1)])' with 3 states
# Done training!
# ******************** FHMM 10min mean********************
# Training model for submeter 'ElecMeter(instance=5, building=1, dataset='DEPS', appliances=[Appliance(type='light', instance=1)])' with 3 states
# Training model for submeter 'ElecMeter(instance=6, building=1, dataset='DEPS', appliances=[Appliance(type='light', instance=2)])' with 3 states
# Training model for submeter 'ElecMeter(instance=7, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=1)])' with 3 states
# Training model for submeter 'ElecMeter(instance=8, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=2)])' with 3 states
# Training model for submeter 'ElecMeter(instance=9, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=3)])' with 3 states
# Training model for submeter 'ElecMeter(instance=10, building=1, dataset='DEPS', appliances=[Appliance(type='server computer', instance=1)])' with 3 states
# ******************** CO 10min median********************
# Training model for submeter 'ElecMeter(instance=5, building=1, dataset='DEPS', appliances=[Appliance(type='light', instance=1)])' with 2 states
# Training model for submeter 'ElecMeter(instance=6, building=1, dataset='DEPS', appliances=[Appliance(type='light', instance=2)])' with 2 states
# Training model for submeter 'ElecMeter(instance=7, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=1)])' with 3 states
# Training model for submeter 'ElecMeter(instance=8, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=2)])' with 3 states
# Training model for submeter 'ElecMeter(instance=9, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=3)])' with 3 states
# Training model for submeter 'ElecMeter(instance=10, building=1, dataset='DEPS', appliances=[Appliance(type='server computer', instance=1)])' with 3 states
# Done training!
# ******************** FHMM 10min median********************
# Training model for submeter 'ElecMeter(instance=5, building=1, dataset='DEPS', appliances=[Appliance(type='light', instance=1)])' with 2 states
# Training model for submeter 'ElecMeter(instance=6, building=1, dataset='DEPS', appliances=[Appliance(type='light', instance=2)])' with 2 states
# Training model for submeter 'ElecMeter(instance=7, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=1)])' with 3 states
# Training model for submeter 'ElecMeter(instance=8, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=2)])' with 3 states
# Training model for submeter 'ElecMeter(instance=9, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=3)])' with 3 states
# Training model for submeter 'ElecMeter(instance=10, building=1, dataset='DEPS', appliances=[Appliance(type='server computer', instance=1)])' with 3 states
# ******************** CO 15min mean********************
# Training model for submeter 'ElecMeter(instance=5, building=1, dataset='DEPS', appliances=[Appliance(type='light', instance=1)])' with 3 states
# Training model for submeter 'ElecMeter(instance=6, building=1, dataset='DEPS', appliances=[Appliance(type='light', instance=2)])' with 3 states
# Training model for submeter 'ElecMeter(instance=7, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=1)])' with 3 states
# Training model for submeter 'ElecMeter(instance=8, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=2)])' with 3 states
# Training model for submeter 'ElecMeter(instance=9, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=3)])' with 3 states
# Training model for submeter 'ElecMeter(instance=10, building=1, dataset='DEPS', appliances=[Appliance(type='server computer', instance=1)])' with 3 states
# Done training!
# ******************** FHMM 15min mean********************
# Training model for submeter 'ElecMeter(instance=5, building=1, dataset='DEPS', appliances=[Appliance(type='light', instance=1)])' with 3 states
# Training model for submeter 'ElecMeter(instance=6, building=1, dataset='DEPS', appliances=[Appliance(type='light', instance=2)])' with 3 states
# Training model for submeter 'ElecMeter(instance=7, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=1)])' with 3 states
# Training model for submeter 'ElecMeter(instance=8, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=2)])' with 3 states
# Training model for submeter 'ElecMeter(instance=9, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=3)])' with 3 states
# Training model for submeter 'ElecMeter(instance=10, building=1, dataset='DEPS', appliances=[Appliance(type='server computer', instance=1)])' with 3 states
# ******************** CO 15min median********************
# Training model for submeter 'ElecMeter(instance=5, building=1, dataset='DEPS', appliances=[Appliance(type='light', instance=1)])' with 2 states
# Training model for submeter 'ElecMeter(instance=6, building=1, dataset='DEPS', appliances=[Appliance(type='light', instance=2)])' with 2 states
# Training model for submeter 'ElecMeter(instance=7, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=1)])' with 3 states
# Training model for submeter 'ElecMeter(instance=8, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=2)])' with 3 states
# Training model for submeter 'ElecMeter(instance=9, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=3)])' with 3 states
# Training model for submeter 'ElecMeter(instance=10, building=1, dataset='DEPS', appliances=[Appliance(type='server computer', instance=1)])' with 3 states
# Done training!
# ******************** FHMM 15min median********************
# Training model for submeter 'ElecMeter(instance=5, building=1, dataset='DEPS', appliances=[Appliance(type='light', instance=1)])' with 2 states
# Training model for submeter 'ElecMeter(instance=6, building=1, dataset='DEPS', appliances=[Appliance(type='light', instance=2)])' with 2 states
# Training model for submeter 'ElecMeter(instance=7, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=1)])' with 3 states
# Training model for submeter 'ElecMeter(instance=8, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=2)])' with 3 states
# Training model for submeter 'ElecMeter(instance=9, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=3)])' with 3 states
# Training model for submeter 'ElecMeter(instance=10, building=1, dataset='DEPS', appliances=[Appliance(type='server computer', instance=1)])' with 3 states
# ******************** CO 30min mean********************
# Training model for submeter 'ElecMeter(instance=5, building=1, dataset='DEPS', appliances=[Appliance(type='light', instance=1)])' with 3 states
# Training model for submeter 'ElecMeter(instance=6, building=1, dataset='DEPS', appliances=[Appliance(type='light', instance=2)])' with 3 states
# Training model for submeter 'ElecMeter(instance=7, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=1)])' with 3 states
# Training model for submeter 'ElecMeter(instance=8, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=2)])' with 3 states
# Training model for submeter 'ElecMeter(instance=9, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=3)])' with 3 states
# Training model for submeter 'ElecMeter(instance=10, building=1, dataset='DEPS', appliances=[Appliance(type='server computer', instance=1)])' with 3 states
# Done training!
# ******************** FHMM 30min mean********************
# Training model for submeter 'ElecMeter(instance=5, building=1, dataset='DEPS', appliances=[Appliance(type='light', instance=1)])' with 3 states
# Training model for submeter 'ElecMeter(instance=6, building=1, dataset='DEPS', appliances=[Appliance(type='light', instance=2)])' with 3 states
# Training model for submeter 'ElecMeter(instance=7, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=1)])' with 3 states
# Training model for submeter 'ElecMeter(instance=8, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=2)])' with 3 states
# Training model for submeter 'ElecMeter(instance=9, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=3)])' with 3 states
# Training model for submeter 'ElecMeter(instance=10, building=1, dataset='DEPS', appliances=[Appliance(type='server computer', instance=1)])' with 3 states
# ******************** CO 30min median********************
# Training model for submeter 'ElecMeter(instance=5, building=1, dataset='DEPS', appliances=[Appliance(type='light', instance=1)])' with 2 states
# Training model for submeter 'ElecMeter(instance=6, building=1, dataset='DEPS', appliances=[Appliance(type='light', instance=2)])' with 2 states
# Training model for submeter 'ElecMeter(instance=7, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=1)])' with 3 states
# Training model for submeter 'ElecMeter(instance=8, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=2)])' with 3 states
# Training model for submeter 'ElecMeter(instance=9, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=3)])' with 3 states
# Training model for submeter 'ElecMeter(instance=10, building=1, dataset='DEPS', appliances=[Appliance(type='server computer', instance=1)])' with 3 states
# Done training!
# ******************** FHMM 30min median********************
# Training model for submeter 'ElecMeter(instance=5, building=1, dataset='DEPS', appliances=[Appliance(type='light', instance=1)])' with 2 states
# Training model for submeter 'ElecMeter(instance=6, building=1, dataset='DEPS', appliances=[Appliance(type='light', instance=2)])' with 2 states
# Training model for submeter 'ElecMeter(instance=7, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=1)])' with 3 states
# Training model for submeter 'ElecMeter(instance=8, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=2)])' with 3 states
# Training model for submeter 'ElecMeter(instance=9, building=1, dataset='DEPS', appliances=[Appliance(type='air conditioner', instance=3)])' with 3 states
# Training model for submeter 'ElecMeter(instance=10, building=1, dataset='DEPS', appliances=[Appliance(type='server computer', instance=1)])' with 3 states
#
#
# Done!

# %%
#tiempos de simulación: entrenamiento
times_t2.transpose()
# Out:
#        CO_mean  FHMM_mean  CO_median  FHMM_median
# 10s       3.75      11.60       3.87        10.43
# 30s       3.80       6.69       3.87         6.26
# 60s       3.74       5.70       3.77         5.11
# 5min      3.11       4.43       3.51         4.23
# 10min     2.94       3.59       2.98         3.44
# 15min     2.56       3.33       2.65         3.34
# 30min     2.62       3.09       2.49         2.88
